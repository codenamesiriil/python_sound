# %% [markdown]
# # **Sine Wave**
#
# $$
# s(t)=A\sin(2\pi f t+\varphi)
# $$
#
# ---

# %%
import numpy as np
from scipy.io.wavfile import write
from IPython.display import Audio

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('xtick', labelsize=7) 
mpl.rc('ytick', labelsize=7) 

# %matplotlib inline

# %%
sr  = 44100   # sample rate
dr  = 1       # duration in seconds
fq  = 800     # frequency in Hz
amp = 0.5     # amplitude

timev    = np.linspace(0, dr, dr*sr)           # creates a time vector
signal   = amp*np.sin(2*np.pi*fq*timev)        # generates a signal

sig_fft  = np.fft.fft(signal)                  # fast fourier transform
sig_fftn = np.abs(sig_fft) / sr*2              # normalizes values for the plot

# %% [markdown]
# ---
#
# #### **Plotting the signal**

# %%
fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1)
fig.tight_layout(h_pad=4)

# plotting wave form
ax1.hlines(y=0, xmin=0, xmax=0.01, linewidth= 0.5, color='orange')
ax1.plot(timev, signal, '.-')
ax1.set_xlabel('Time (milliseconds)')
ax1.set_ylabel('Amplitude')
ax1.set_xlim(0, 0.01)

# plotting frequency
ax2.plot(sig_fftn)
ax2.set_xlabel('Frequency ($Hz$)')
ax2.set_ylabel('Amplitude')
ax2.set_xlim(0, 1000)

plt.show()

# %% [markdown]
# ---
#
# #### **Creating an audio file**

# %%
sin_sound = np.int16(signal*32767)       # converting values into 16 bit intengers

write('sin_sound.wav', 44100, sin_sound)
Audio(data='sin_sound.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
#
# #### **Phase**

# %%
phs1 = 0
phs2 = np.pi/2
phs3 = 3*np.pi/2
phs4 = np.pi

signal1   = amp*np.sin(2*np.pi*fq*timev+phs1)
signal2   = amp*np.sin(2*np.pi*fq*timev+phs2) 
signal3   = amp*np.sin(2*np.pi*fq*timev+phs3) 
signal4   = amp*np.sin(2*np.pi*fq*timev+phs4)

# %%
fig, ax3 = plt.subplots(nrows=2, ncols=2)

# plotting phase 1
ax3[0, 0].hlines(y=0, xmin=0, xmax=0.01, linewidth= 0.5, color='orange')
ax3[0, 0].plot(timev, signal1, '.-')
ax3[0, 0].set_xlabel('Time (milliseconds)')
ax3[0, 0].set_ylabel('Amplitude')
ax3[0, 0].set_xlim(0, 0.005)

# plotting phase 2
ax3[0, 1].hlines(y=0, xmin=0, xmax=0.01, linewidth= 0.5, color='orange')
ax3[0, 1].plot(timev, signal2, '.-')
ax3[0, 1].set_xlabel('Time (milliseconds)')
ax3[0, 1].set_ylabel('Amplitude')
ax3[0, 1].set_xlim(0, 0.005)

# plotting phase 1
ax3[1, 0].hlines(y=0, xmin=0, xmax=0.01, linewidth= 0.5, color='orange')
ax3[1, 0].plot(timev, signal3, '.-')
ax3[1, 0].set_xlabel('Time (milliseconds)')
ax3[1, 0].set_ylabel('Amplitude')
ax3[1, 0].set_xlim(0, 0.005)

# plotting phase 1
ax3[1, 1].hlines(y=0, xmin=0, xmax=0.01, linewidth= 0.5, color='orange')
ax3[1, 1].plot(timev, signal4, '.-')
ax3[1, 1].set_xlabel('Time (milliseconds)')
ax3[1, 1].set_ylabel('Amplitude')
ax3[1, 1].set_xlim(0, 0.005)

fig.tight_layout(h_pad=2)
plt.show()
